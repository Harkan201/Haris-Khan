# %%
import random
import random
from collections import Counter

def hat_problem():
    # Initialize the hat with numbers 1 through 10
    hat = list(range(1, 5))

    # Repeat the process until only one number remains
    while len(hat) > 1:
        # Draw two numbers at random from the hat
        x, y = random.sample(hat, 2)
        # Calculate the difference
        diff = abs(x - y)
        # Remove the drawn numbers from the hat
        hat.remove(x)
        hat.remove(y)
        # Add the difference to the hat
        hat.append(diff)

    # Return the final remaining number
    return hat[0]

# Run the simulation
result = hat_problem()
print("The final remaining number is:", result)

# Run the simulation 100 times
results = []
for _ in range(100):
    result = hat_problem()
    results.append(result)

# Print all the results
print("Results of 100 simulations:")
print(results)
occurrences = Counter(results)

# Print the occurrences of each number
print("Occurrences of each number:")
for number, count in occurrences.items():
    print(f"Number {number}: {count} times")

# Plot a histogram of the results
plt.bar(occurrences.keys(), occurrences.values())
plt.xlabel('Number')
plt.ylabel('Occurrences')
plt.title('Histogram of Results')
plt.show()
# Out:
# The final remaining number is: 0
# Results of 100 simulations:
# [2, 4, 2, 2, 2, 0, 0, 2, 4, 2, 2, 0, 0, 2, 2, 0, 0, 2, 0, 2, 4, 0, 0, 4, 2, 4, 0, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0, 0, 0, 0, 4, 2, 2, 0, 2, 0, 2, 4, 0, 2, 2, 0, 4, 2, 2, 0, 2, 4, 0, 2, 0, 2, 4, 0, 2, 4, 0, 4, 0, 0, 0, 2, 0, 2, 0, 2, 4, 4, 0, 0, 0, 0, 2, 2, 2, 4, 4, 2, 0, 2, 4, 2]
# Occurrences of each number:
# Number 2: 43 times
# Number 4: 17 times
# Number 0: 40 times

# %%
import random
from collections import Counter

def hat_problem():
    # Initialize the hat with numbers 1 through 10
    hat = list(range(1, 7))

    # Repeat the process until only one number remains
    while len(hat) > 1:
        # Draw two numbers at random from the hat
        x, y = random.sample(hat, 2)
        # Calculate the difference
        diff = abs(x - y)
        # Remove the drawn numbers from the hat
        hat.remove(x)
        hat.remove(y)
        # Add the difference to the hat
        hat.append(diff)

    # Return the final remaining number
    return hat[0]

# Run the simulation
result = hat_problem()
print("The final remaining number is:", result)

# Run the simulation 100 times
results = []
for _ in range(100):
    result = hat_problem()
    results.append(result)

# Print all the results
print("Results of 100 simulations:")
print(results)
occurrences = Counter(results)

# Print the occurrences of each number
print("Occurrences of each number:")
for number, count in occurrences.items():
    print(f"Number {number}: {count} times")
# Out:
# The final remaining number is: 3
# Results of 100 simulations:
# [1, 1, 3, 3, 3, 1, 1, 3, 3, 3, 1, 3, 5, 5, 1, 3, 1, 1, 3, 3, 1, 5, 1, 1, 3, 5, 1, 1, 3, 3, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 1, 3, 1, 1, 1, 1, 3, 5, 1, 5, 1, 1, 3, 1, 1, 1, 1, 5, 1, 3, 3, 1, 1, 1, 3, 3, 1, 1, 1, 5, 1, 3, 1, 1, 1, 3, 1, 3, 1, 1, 1, 1, 1, 1, 1, 3, 1, 5, 5, 1, 1, 3, 1, 1]
# Occurrences of each number:
# Number 1: 61 times
# Number 3: 29 times
# Number 5: 10 times

# %%
def hat_problem():
    # Initialize the hat with numbers 1 through 10
    hat = list(range(1, 2025))

    # Repeat the process until only one number remains
    while len(hat) > 1:
        # Draw two numbers at random from the hat
        x, y = random.sample(hat, 2)
        # Calculate the difference
        diff = abs(x - y)
        # Remove the drawn numbers from the hat
        hat.remove(x)
        hat.remove(y)
        # Add the difference to the hat
        hat.append(diff)

    # Return the final remaining number
    return hat[0]

# Run the simulation
result = hat_problem()
print("The final remaining number is:", result)

# Run the simulation 100 times
results = []
for _ in range(100):
    result = hat_problem()
    results.append(result)

# Print all the results
print("Results of 100 simulations:")
print(results)
occurrences = Counter(results)

# Print the occurrences of each number
print("Occurrences of each number:")
for number, count in occurrences.items():
    print(f"Number {number}: {count} times")




# Plot a histogram of the results
plt.bar(occurrences.keys(), occurrences.values())
plt.xlabel('Number')
plt.ylabel('Occurrences')
plt.title('Histogram of Results')
plt.show()
# Out:
# The final remaining number is: 208
# Results of 100 simulations:
# [224, 1246, 158, 362, 86, 316, 810, 512, 158, 190, 76, 64, 394, 192, 944, 14, 436, 130, 60, 302, 442, 234, 6, 712, 456, 178, 502, 20, 718, 1194, 86, 30, 46, 596, 66, 710, 1204, 492, 302, 200, 430, 98, 1088, 448, 822, 702, 222, 186, 940, 756, 536, 266, 174, 92, 154, 492, 268, 204, 2, 740, 262, 574, 54, 248, 138, 736, 56, 150, 44, 396, 272, 578, 612, 438, 250, 126, 742, 10, 90, 172, 194, 276, 218, 420, 332, 234, 402, 408, 348, 302, 542, 374, 868, 322, 56, 610, 748, 60, 114, 472]
# Occurrences of each number:
# Number 224: 1 times
# Number 1246: 1 times
# Number 158: 2 times
# Number 362: 1 times
# Number 86: 2 times
# Number 316: 1 times
# Number 810: 1 times
# Number 512: 1 times
# Number 190: 1 times
# Number 76: 1 times
# Number 64: 1 times
# Number 394: 1 times
# Number 192: 1 times
# Number 944: 1 times
# Number 14: 1 times
# Number 436: 1 times
# Number 130: 1 times
# Number 60: 2 times
# Number 302: 3 times
# Number 442: 1 times
# Number 234: 2 times
# Number 6: 1 times
# Number 712: 1 times
# Number 456: 1 times
# Number 178: 1 times
# Number 502: 1 times
# Number 20: 1 times
# Number 718: 1 times
# Number 1194: 1 times
# Number 30: 1 times
# Number 46: 1 times
# Number 596: 1 times
# Number 66: 1 times
# Number 710: 1 times
# Number 1204: 1 times
# Number 492: 2 times
# Number 200: 1 times
# Number 430: 1 times
# Number 98: 1 times
# Number 1088: 1 times
# Number 448: 1 times
# Number 822: 1 times
# Number 702: 1 times
# Number 222: 1 times
# Number 186: 1 times
# Number 940: 1 times
# Number 756: 1 times
# Number 536: 1 times
# Number 266: 1 times
# Number 174: 1 times
# Number 92: 1 times
# Number 154: 1 times
# Number 268: 1 times
# Number 204: 1 times
# Number 2: 1 times
# Number 740: 1 times
# Number 262: 1 times
# Number 574: 1 times
# Number 54: 1 times
# Number 248: 1 times
# Number 138: 1 times
# Number 736: 1 times
# Number 56: 2 times
# Number 150: 1 times
# Number 44: 1 times
# Number 396: 1 times
# Number 272: 1 times
# Number 578: 1 times
# Number 612: 1 times
# Number 438: 1 times
# Number 250: 1 times
# Number 126: 1 times
# Number 742: 1 times
# Number 10: 1 times
# Number 90: 1 times
# Number 172: 1 times
# Number 194: 1 times
# Number 276: 1 times
# Number 218: 1 times
# Number 420: 1 times
# Number 332: 1 times
# Number 402: 1 times
# Number 408: 1 times
# Number 348: 1 times
# Number 542: 1 times
# Number 374: 1 times
# Number 868: 1 times
# Number 322: 1 times
# Number 610: 1 times
# Number 748: 1 times
# Number 114: 1 times
# Number 472: 1 times

# %%
import random
from collections import Counter

def hat_problem(n):
    # Initialize the hat with numbers 1 through 10
    hat = list(range(1, n+1))

    # Repeat the process until only one number remains
    while len(hat) > 1:
        # Draw two numbers at random from the hat
        x, y = random.sample(hat, 2)
        # Calculate the difference
        diff = abs(x - y)
        # Remove the drawn numbers from the hat
        hat.remove(x)
        hat.remove(y)
        # Add the difference to the hat
        hat.append(diff)

    # Return the final remaining number
    return hat[0]

def iterate_hat_problem(n,iterations):
    results = []
    for _ in range(iterations):
        result = hat_problem(n)
        results.append(result)
    occurrences = Counter(results)
    return occurrences

def print_hat_problem(n,iterations):
    occurrences = iterate_hat_problem(n,iterations)
    print("Occurrences of each number:")
    total = 1
    # my_array = [0] * (n+1)
    for i in range(2,n+1):
        total = total * (2*i -3)
    for number, count in occurrences.items():
        num = round(total *count/iterations)
        print(f"Number {number}: {count}   \t times : {num}/{total} %")
        # my_array[number] = count
        # prob = count/iterations
        # print(f"Number {number}: {count}   \t times : {prob}%")
    # print(my_array)

print_hat_problem(20,10500)
# Out:
# Occurrences of each number:
# Number 2: 2527   	 times : 1973657884188185985024/8200794532637891559375 %
# Number 6: 1500   	 times : 1171542076091127300096/8200794532637891559375 %
# Number 8: 1104   	 times : 862254968003069739008/8200794532637891559375 %
# Number 10: 768   	 times : 599829542958657175552/8200794532637891559375 %
# Number 0: 1526   	 times : 1191848805410040184832/8200794532637891559375 %
# Number 16: 196   	 times : 153081497942573973504/8200794532637891559375 %
# Number 14: 321   	 times : 250710004283501248512/8200794532637891559375 %
# Number 4: 1958   	 times : 1529252923324284796928/8200794532637891559375 %
# Number 12: 533   	 times : 416287951037713940480/8200794532637891559375 %
# Number 18: 58   	 times : 45299626942190256128/8200794532637891559375 %
# Number 20: 9   	 times : 7029252456546763776/8200794532637891559375 %

# %%
import random
import random
from collections import Counter

def hat_problem():
    # Initialize the hat with numbers 1 through 10
    hat = list(range(1, 41))

    # Repeat the process until only one number remains
    while len(hat) > 1:
        # Draw two numbers at random from the hat
        x, y = random.sample(hat, 2)
        # Calculate the difference
        diff = abs(x - y)
        # Remove the drawn numbers from the hat
        hat.remove(x)
        hat.remove(y)
        # Add the difference to the hat
        hat.append(diff)

    # Return the final remaining number
    return hat[0]

# Run the simulation
result = hat_problem()
print("The final remaining number is:", result)

# Run the simulation 100 times
results = []
for _ in range(1000):
    result = hat_problem()
    results.append(result)

# Print all the results
print("Results of 100 simulations:")
print(results)
occurrences = Counter(results)

# Print the occurrences of each number
print("Occurrences of each number:")
for number, count in occurrences.items():
    print(f"Number {number}: {count} times")

# Plot a histogram of the results
plt.bar(occurrences.keys(), occurrences.values())
plt.xlabel('Number')
plt.ylabel('Occurrences')
plt.title('Histogram of Results')
plt.show()
# Out:
# The final remaining number is: 20
# Results of 100 simulations:
 2, 0, 8, 0, 6, 18, 4, 0, 6, 2, 10, 10, 2, 8, 8, 0, 12, 30, 10, 10, 8, 14, 10, 10, 8, 10, 20, 10, 10, 4, 12, 10, 6, 4, 2, 4, 2, 0, 8, 16, 4, 6, 2, 4, 2, 8, 0, 18, 10, 10, 14, 0, 0, 0, 2, 18, 14, 2, 8, 10, 20, 14, 16, 2, 6, 14, 12, 4, 4, 16, 12, 2, 12, 12, 12, 12, 12, 6, 2, 8, 28, 2, 6, 4, 22, 0, 8, 2, 8, 0, 16, 20, 20, 20, 0, 12, 14, 20, 10, 28, 0, 18, 2, 28, 8, 6, 10, 2, 22, 2, 12, 10, 4, 12, 16, 6, 8, 2, 4, 2, 8, 12, 6, 18, 2, 4, 2, 0, 12, 8, 2, 2, 18, 10, 22, 4, 14, 8, 8, 0, 8, 2, 10, 6, 2, 0, 4, 16, 16, 12, 6, 24, 10, 10, 2, 16, 14, 4, 32, 14, 16, 2, 8, 0, 10, 2, 22, 32, 2, 4, 14, 2, 2, 6, 2, 8, 8, 8, 4, 10, 2, 16, 4, 18, 14, 16, 0, 4, 18, 18, 12, 8, 12, 2, 4, 0, 2, 6, 18, 0, 4, 10, 8, 2, 6, 8, 16, 10, 14, 22, 6, 4, 0, 26, 8, 0, 28, 12, 4, 12, 0, 2, 8, 8, 2, 4, 6, 2, 22, 0, 2, 16, 16, 4, 2, 24, 10, 8, 18, 4, 4, 2, 26, 2, 10, 24, 18, 8, 18, 2, 4, 10, 14, 6, 18, 8, 2, 4, 4, 4, 10, 16, 18, 18, 24, 24, 18, 2, 6, 10, 18, 20, 2, 4, 4, 2, 2, 16, 2, 2, 0, 4, 12, 18, 0, 0, 2, 16, 12, 4, 6, 4, 4, 16, 6, 8, 0, 2, 14, 6, 0, 2, 2, 2, 10, 10, 2, 24, 6, 12, 20, 4, 14, 14, 6, 20, 2, 2, 8, 8, 6, 12, 14, 2, 2, 36, 2, 14, 2, 6, 10, 2, 20, 0, 0, 14, 0, 10, 2, 20, 6, 4, 4, 2, 6, 6, 18, 2, 10, 14, 8, 4, 0, 6, 16, 8, 4, 4, 2, 16, 2, 8, 28, 14, 16, 6, 6, 2, 12, 2, 0, 18, 2, 6, 2, 14, 22, 14, 14, 16, 8, 6, 6, 2, 16, 14, 6, 10, 2, 12, 8, 4, 18, 2, 2, 14, 2, 12, 14, 4, 6, 0, 6, 4, 4, 16, 18, 12, 16, 0, 6, 4, 2, 4, 4, 4, 20, 2, 0, 2, 4, 12, 8, 12, 8, 2, 16, 16, 10, 4, 6, 4, 4, 32, 2, 6, 10, 10, 2]
# Occurrences of each number:
# Number 26: 8 times
# Number 8: 92 times
# Number 0: 86 times
# Number 2: 159 times
# Number 6: 116 times
# Number 30: 10 times
# Number 12: 54 times
# Number 28: 16 times
# Number 10: 84 times
# Number 4: 130 times
# Number 14: 70 times
# Number 34: 3 times
# Number 24: 17 times
# Number 16: 49 times
# Number 22: 27 times
# Number 20: 27 times
# Number 38: 1 times
# Number 18: 44 times
# Number 36: 3 times
# Number 32: 4 times

# %%
std_dev = np.std(results)
print("Standard deviation of the histogram:", std_dev)
# Out:
# Standard deviation of the histogram: 7.686784375797203
